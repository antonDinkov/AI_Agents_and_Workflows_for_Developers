# %% [markdown]
# <a href="https://colab.research.google.com/github/antonDinkov/AI_Agents_and_Workflows_for_Developers/blob/main/LangChain_Agents_Tools_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initial instalation

# %%
# !pip install -q langchain langchain-openai langchain-community

# %% [markdown]
# # Imports

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import TextLoader
from google.colab import userdata
from langchain.messages import HumanMessage
from langchain_core.messages import BaseMessage
from typing import List

# %% [markdown]
# # Helpers

# %%
def print_conversation(messages: List[BaseMessage]) -> None:
  for message in messages:
    message.pretty_print()

# %% [markdown]
# # Instances

# %%
api_key_openai = userdata.get("OPEN_AI_API_KEY")
model_instance = ChatOpenAI(
    model="gpt-5.6-luna",
    api_key=api_key_openai
)
text_loader = TextLoader(file_path="/content/FAQ.md")

# %%
documents = text_loader.load()
system_prompt_fragments = ["You are a helpful customer support agent"]
system_prompt_fragments.extend(d.page_content for d in documents)

# %%
system_prompt_fragments
# Out:
# ['You are a helpful customer support agent',
#  "# Store FAQ\n\nWelcome to our customer support FAQ. This document contains the official store policies for warranty, repairs, returns, shipping, payments, order changes, and customer support.\n\n---\n\n## Q1. What is the warranty?\n\nFor individual customers, products include a **24-month warranty** from the date of purchase.\n\nFor companies and other legal entities, the warranty period is **12 months** from the date of purchase.\n\nThe warranty covers manufacturing defects and hardware failures that occur during normal use.\n\nThe warranty does **not** cover:\n- Mechanical or accidental damage\n- Cracked screens caused by impact or dropping\n- Liquid or moisture damage\n- Damage caused by improper use\n- Unauthorized repairs or modifications\n- Normal cosmetic wear and tear\n- Damage caused by incompatible accessories or chargers\n\nA valid invoice, receipt, or other proof of purchase may be required for warranty service.\n\n---\n\n## Q2. How do I make a warranty claim?\n\nA warranty claim can be submitted through the support form on our website or by contacting customer support.\n\nPlease include:\n- Your order or invoice number\n- The product name or model\n- A short description of the problem\n- Photos showing the defect, when applicable\n- Your contact details\n\nOur service department normally responds within **2 business days**.\n\nFor approved warranty claims, we cover the standard transportation costs associated with sending the defective product for inspection and returning the repaired or replacement product.\n\n---\n\n## Q3. How long does a warranty repair take?\n\nWarranty repairs may take up to **30 calendar days** after the product has been received and accepted for service.\n\nIn many cases, repairs are completed sooner.\n\nIf the required spare part is unavailable or the product cannot reasonably be repaired, we may offer:\n1. A replacement product of the same or an equivalent model, subject to availability; or\n2. A refund, where applicable.\n\nThe customer will be informed if additional time or information is required.\n\n---\n\n## Q4. Can I return an order?\n\nYes. Products may be returned within **14 days of receiving the order**, provided that the applicable return conditions are met.\n\nTo qualify for a standard return:\n- The product should be returned in good condition.\n- The original packaging should be preserved.\n- All included accessories, manuals, cables, and other components should be returned.\n- Proof of purchase should be provided.\n\nAfter an eligible return is received and inspected, the refund is issued within **14 days**.\n\nProducts that show damage caused by improper handling may not qualify for a full refund.\n\n---\n\n## Q5. What are the delivery times?\n\n### Sofia\n\nOrders placed before **4:00 PM on a business day** are normally delivered within **24 hours**.\n\nOrders placed after 4:00 PM, during weekends, or on public holidays are processed on the next business day.\n\n### Nationwide delivery\n\nOrders to other locations in Bulgaria are normally delivered within **1–3 business days**.\n\nDelivery times may be longer for remote locations, public holidays, severe weather, or courier delays.\n\n### Free delivery\n\nStandard delivery is **free for orders over BGN 150**.\n\nOrders below BGN 150 may include a delivery charge depending on the destination and selected delivery method.\n\n---\n\n## Q6. What payment methods do you accept?\n\nWe accept the following payment methods:\n- Credit and debit cards\n- Cash on delivery\n- Bank transfer\n\nFor bank transfers, an order may be processed after the payment has been received and confirmed.\n\nAvailable payment methods may vary depending on the delivery method and order type.\n\n---\n\n## Q7. Can I change or cancel my order?\n\nYes, if the order has not yet been dispatched.\n\nContact customer support as soon as possible and provide your order number.\n\nWe will try to change or cancel the order before it is handed over to the courier. ...

# %% [markdown]
# # The agent

# %%
agent = create_agent(
    model=model_instance,
    tools=[

    ],
    system_prompt="\n\n\n".join(system_prompt_fragments),
    debug=True
)

# %%
answer = agent.invoke(input={"messages": [HumanMessage("Hello! How long should I wait for a standard delivery? Do you offer an express option?")]})
# Out:
# [values] {'messages': [HumanMessage(content='Hello! How long should I wait for a standard delivery? Do you offer an express option?', additional_kwargs={}, response_metadata={}, id='0a5b160a-56e6-4f08-992a-8dbb9bebc493')]}
# [updates] {'model': {'messages': [AIMessage(content='Hello! Standard delivery times are:\n\n- **Sofia:** Normally within **24 hours** for orders placed before **4:00 PM on a business day**.\n- **Other locations in Bulgaria:** Normally **1–3 business days**.\n\nOrders placed after 4:00 PM, on weekends, or on public holidays are processed on the next business day. Remote locations, holidays, severe weather, and courier delays may extend delivery times.\n\nThe FAQ does not specify whether an express delivery option is available. Please contact customer support with your destination and order details to confirm available delivery methods.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 121, 'prompt_tokens': 1551, 'total_tokens': 1672, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': 23, 'cached_tokens': 1525}}, 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna', 'system_fingerprint': None, 'id': 'chatcmpl-EG64oy6BYAI7xDyEOIdqI4pKCaumw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02f9e-8720-7401-b4dc-ce6440e13edd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1551, 'output_tokens': 121, 'total_tokens': 1672, 'input_token_details': {'audio': 0, 'cache_read': 1525, 'cache_creation': 23}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Hello! How long should I wait for a standard delivery? Do you offer an express option?', additional_kwargs={}, response_metadata={}, id='0a5b160a-56e6-4f08-992a-8dbb9bebc493'), AIMessage(content='Hello! Standard delivery times are:\n\n- **Sofia:** Normally within **24 hours** for orders placed before **4:00 PM on a business day**.\n- **Other locations in Bulgaria:** Normally **1–3 business days**.\n\nOrders placed after 4:00 PM, on weekends, or on public holidays are processed on the next business day. Remote locations, holidays, severe weather, and courier delays may extend delivery times.\n\nThe FAQ does not specify whether an express delivery option is available. Please contact customer support with your destination and order details to confirm available delivery methods.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 121, 'prompt_tokens': 1551, 'total_tokens': 1672, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': 23, 'cached_tokens': 1525}}, 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna', 'system_fingerprint': None, 'id': 'chatcmpl-EG64oy6BYAI7xDyEOIdqI4pKCaumw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02f9e-8720-7401-b4dc-ce6440e13edd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1551, 'output_tokens': 121, 'total_tokens': 1672, 'input_token_details': {'audio': 0, 'cache_read': 1525, 'cache_creation': 23}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print_conversation(answer['messages'])
# Out:
# ================================ Human Message =================================
#
# Hello! How long should I wait for a standard delivery? Do you offer an express option?
# ================================== Ai Message ==================================
#
# Hello! Standard delivery times are:
#
# - **Sofia:** Normally within **24 hours** for orders placed before **4:00 PM on a business day**.
# - **Other locations in Bulgaria:** Normally **1–3 business days**.
#
# Orders placed after 4:00 PM, on weekends, or on public holidays are processed on the next business day. Remote locations, holidays, severe weather, and courier delays may extend delivery times.
#
# The FAQ does not specify whether an express delivery option is available. Please contact customer support with your destination and order details to confirm available delivery methods.
